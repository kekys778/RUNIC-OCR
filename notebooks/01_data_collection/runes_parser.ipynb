# %%
import pandas as pd

# %%
df = pd.read_csv('runic_inscriptions_20251228_140136.csv')

# %%
df.full_text[4]
# Out:
# '\n\n\n\nRuneS\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\n\n\n                                Project\n                                \n\n\n\n\n\n\n\nAbout\n\n\nTerms\n\n\nData sources\n\n\nList of sigla\n\n\nLinks\n\n\n\n\n\nFinds\n\n\nGraph types\n\n\nMap\n\n\nQueries\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                    Search database...\n                \n\n\n\n\n\n\n\n\nNæsbjerg, rosette brooch\n(Næsbjerg-fibula; Næsbjerg rosettfibula)\n\n\n\n\n\n\n\n\n\n\n\nContents\n\n\n\n\n\n\n\n\nNæsbjerg, rosette brooch\n\n\n\nMap\n\n\nBasic data\n\n\nGraph types\n\n\nInformation on the object\n\n\nInformation on the inscription\n\n\nComment\n\n\nLiterature\n\n\nInterpretations\n\n\nImages of runic objects\n\n\nPlace of storage\n\n\nAdditional links\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n            \n            Sigla\n            \n            \n        \n\n\nSJy 46\n                    | EM85;126 | KJ13 | DR EM85;12
# ...

# %%
df = df[(df.transliteration.notna()) &  (df.local_images_count > 0)]

# %%
df
# Out:
#       find_id  findplace country  \
# 0           1        NaN     NaN
# 1           2        NaN     NaN
# 2           3        NaN     NaN
# 3           4        NaN     NaN
# 4           5        NaN     NaN
# ...       ...        ...     ...
# 7094     7764        NaN     NaN
# 7123     7793        NaN     NaN
# 7127     7797        NaN     NaN
# 7128     7798        NaN     NaN
# 7129     7799        NaN     NaN
#
#                                         transliteration  \
# 0                                              hariso |
# 1                                    [0-?](w)iduhudaz |
# 2                                        alugod(0-1Z) |
# 3                                  ekunwod(1-2?)[0-?] |
# 4                                   (w)ara(2-3?)s(1?) |
# ...                                                 ...
# 7094  hul-...-... ...(i)(t) × hak(u)a × (m)arki × þ(...
# 7123                              [...-r · kerþ(i) ...]
# ...
