# %%
letters = '''ᚠ	ᚢ	ᚦ	ᚨ	ᚱ	ᚲ	ᚷ	ᚹ	ᚺ	ᚾ	ᛁ	ᛃ	ᛈ	ᛇ	ᛉ	ᛊ	ᛏ	ᛒ	ᛖ	ᛗ	ᛚ	ᛜ	ᛞ	ᛟ
f	u	þ	a	r	k	g	w	h	n	i	j	p	ï	z	s	t	b	e	m	l	ŋ	d	o'''
letters = letters.split

# %%
propmpt_text = """You are an expert epigrapher specializing in Elder Futhark runic inscriptions (200-700 CE).

## YOUR TASK
Perform accurate OCR of the runic carving shown in the image.

## ELDER FUTHARK REFERENCE TABLE
Use ONLY these 24 runes:
ᚠ = F  (two diagonal branches pointing right from vertical)
ᚢ = U  (V-shape or two diagonals going down)
ᚦ = TH (vertical with triangle/thorn on right)
ᚨ = A  (vertical with two diagonals forming peak at top)
ᚱ = R  (vertical with diagonal leg going right-down)
ᚲ = K  (vertical with two diagonals pointing left)
ᚷ = G  (vertical with X or diagonal cross)
ᚹ = W  (vertical with bent branches)
ᚺ = H  (two verticals connected by horizontal)
ᚾ = N  (two verticals with diagonal between them)
ᛁ = I  (single vertical stroke)
ᛃ = J  (vertical with curved/diagonal branch)
ᛈ = P  (vertical with triangle pointing left)
ᛇ = EI (vertical with multiple horizontals)
ᛉ = Z  (vertical with X branches at top and bottom)
ᛊ = S  (diagonal zigzag or lightning bolt)
ᛏ = T  (vertical with two short diagonals at top, arrow-like)
ᛒ = B  (vertical with two bumps/triangles on right)
ᛖ = E  (vertical with three horizontals)
ᛗ = M  (two verticals connected with arch)
ᛚ = L  (vertical with single diagonal going right-down)
ᛜ = NG (diamond or rhombus shape)
ᛞ = D  (vertical with diamond/lozenge)
ᛟ = O  (diamond with extending verticals)

## READING GUIDELINES
- Read strictly left to right
- Stone carvings may be weathered — match to closest rune shape
- Watch for bind runes (overlapping runes sharing a stave)
- Vertical main stroke (stave) is common to most runes — identify branches carefully
- Ignore decorative scratches or damage marks

## OUTPUT FORMAT
Return **omly** the rune characters in sequence.
No spaces. No translation. No explanation.
Example output: ᚠᚢᚦᚨᚱᚲ"""

# %%
from groq import Groq
import base64
import os

client = Groq(api_key="YOUR_GROQ_API_KEY")

IMAGE_DIR = r"C:\Users\USER\Desktop\GRAD_WORk\VAL_DATASET_GROQ"
EXTENSIONS = ('.png', '.jpg', '.jpeg', '.webp', '.gif')

def encode_image(path):
    with open(path, "rb") as f:
        return base64.b64encode(f.read()).decode('utf-8')

def ocr_image(image_path):
    ext = os.path.splitext(image_path)[1].lower()
    mime = "image/png" if ext == ".png" else "image/jpeg"
    
    image_data = encode_image(image_path)
    
    response = client.chat.completions.create(
        model="meta-llama/llama-4-scout-17b-16e-instruct",
        messages=[{
            "role": "user",
            "content": [
                {
                    "type": "image_url",
                    "image_url": {"url": f"data:{mime};base64,{image_data}"}
                },
                {
                    "type": "text",
                    "text": propmpt_text
                }
            ]
        }],
        max_tokens=500
    )
    return response.choices[0].message.content

# Обход всех файлов в папке
images = [f for f in os.listdir(IMAGE_DIR) if f.lower().endswith(EXTENSIONS)]
print(f"Найдено изображений: {len(images)}")

results = {}
for filename in images:
    path = os.path.join(IMAGE_DIR, filename)
    print(f"\n--- {filename} ---")
    
    try:
        result = ocr_image(path)
        results[filename] = result
        print(result)
    except Exception as e:
        print(f"Ошибка: {e}")
        results[filename] = f"ERROR: {e}"

# Сохранить результаты
output_path = os.path.join(IMAGE_DIR, "results.txt")
with open(output_path, "w", encoding="utf-8") as f:
    for filename, text in results.items():
        f.write(f"=== {filename} ===\n{text}\n\n")

print(f"\nРезультаты сохранены в {output_path}")
# Out:
# Найдено изображений: 5
#
# --- 14_1.png ---
# Ошибка: Error code: 400 - {'error': {'message': 'messages[0].content must be a string', 'type': 'invalid_request_error', 'param': 'messages[0].content'}}
#
# --- 15_1.jpg ---
# Ошибка: Error code: 400 - {'error': {'message': 'messages[0].content must be a string', 'type': 'invalid_request_error', 'param': 'messages[0].content'}}
#
# --- 16_3._2jpg.jpg ---
# Ошибка: Error code: 400 - {'error': {'message': 'messages[0].content must be a string', 'type': 'invalid_request_error', 'param': 'messages[0].content'}}
#
# --- 53_1.jpg ---
# Ошибка: Error code: 400 - {'error': {'message': 'messages[0].content must be a string', 'type': 'invalid_request_error', 'param': 'messages[0].content'}}
#
# --- 82_1.jpg ---
# Ошибка: Error code: 400 - {'error': {'message': 'messages[0].content must be a string', 'type': 'invalid_request_error', 'param': 'messages[0].content'}}
#
# Результаты сохранены в C:\Users\USER\Desktop\GRAD_WORk\VAL_DATASET_GROQ\results.txt

# %%
letters = letters.split

# %%
print(letters)
# Out:
# ['ᚠ', 'ᚢ', 'ᚦ', 'ᚨ', 'ᚱ', 'ᚲ', 'ᚷ', 'ᚹ', 'ᚺ', 'ᚾ', 'ᛁ', 'ᛃ', 'ᛈ', 'ᛇ', 'ᛉ', 'ᛊ', 'ᛏ', 'ᛒ', 'ᛖ', 'ᛗ', 'ᛚ', 'ᛜ', 'ᛞ', 'ᛟ', 'f', 'u', 'þ', 'a', 'r', 'k', 'g', 'w', 'h', 'n', 'i', 'j', 'p', 'ï', 'z', 's', 't', 'b', 'e', 'm', 'l', 'ŋ', 'd', 'o']

# %%
You are an expert epigrapher specializing in Elder Futhark runic inscriptions (200-700 CE).

## YOUR TASK
Perform accurate OCR of the runic carving shown in the image.

## ELDER FUTHARK REFERENCE TABLE
Use ONLY these 24 runes:
ᚠ = F  (two diagonal branches pointing right from vertical)
ᚢ = U  (V-shape or two diagonals going down)
ᚦ = TH (vertical with triangle/thorn on right)
ᚨ = A  (vertical with two diagonals forming peak at top)
ᚱ = R  (vertical with diagonal leg going right-down)
ᚲ = K  (vertical with two diagonals pointing left)
ᚷ = G  (vertical with X or diagonal cross)
ᚹ = W  (vertical with bent branches)
ᚺ = H  (two verticals connected by horizontal)
ᚾ = N  (two verticals with diagonal between them)
ᛁ = I  (single vertical stroke)
ᛃ = J  (vertical with curved/diagonal branch)
ᛈ = P  (vertical with triangle pointing left)
ᛇ = EI (vertical with multiple horizontals)
ᛉ = Z  (vertical with X branches at top and bottom)
ᛊ = S  (diagonal zigzag or lightning bolt)
ᛏ = T  (vertical with two short diagonals at top, arrow-like)
ᛒ = B  (vertical with two bumps/triangles on right)
ᛖ = E  (vertical with three horizontals)
ᛗ = M  (two verticals connected with arch)
ᛚ = L  (vertical with single diagonal going right-down)
ᛜ = NG (diamond or rhombus shape)
ᛞ = D  (vertical with diamond/lozenge)
ᛟ = O  (diamond with extending verticals)

## READING GUIDELINES
- Read strictly left to right
- Stone carvings may be weathered — match to closest rune shape
- Watch for bind runes (overlapping runes sharing a stave)
- Vertical main stroke (stave) is common to most runes — identify branches carefully
- Ignore decorative scratches or damage marks

## OUTPUT FORMAT
Return **omly** the rune characters in sequence.
No spaces. No translation. No explanation.
Example output: ᚠᚢᚦᚨᚱᚲ

# %% [markdown]
# ### ПРОГОН

# %%
client = Groq(api_key="YOUR_GROQ_API_KEY")

# ==================== GOLDEN DATASET ====================
GOLDEN_DATASET = [
    {"id": "6_1",   "latin": "bidawarijaztalgidai",      "runes": "ᛒᛁᛞᚨᚹᚨᚱᛁᛃᚨᛉᛏᚨᛚᚷᛁᛞᚨᛁ"},
    {"id": "13_0",  "latin": "lua",                      "runes": "ᛚᚢᚨ"},
    {"id": "14_1",  "latin": "owlþuþewaz",               "runes": "ᛟᚹᛚᚦᚢᚦᛖᚹᚨᛉ"},
    {"id": "15_1",  "latin": "ansgzh",                   "runes": "ᚨᚾᛊᚷᛉᚺ"},
    {"id": "16_3_2","latin": "ala",                      "runes": "ᚨᛚᚨ"},
    {"id": "39_1",  "latin": "leþro",                    "runes": "ᛚᛖᚦᚱᛟ"},
    {"id": "42_2",  "latin": "aluko",                    "runes":"ᚨᛚᚢᚲᛟ"},
    {"id": "50_1",  "latin": "heþrodwe^ngk",             "runes": "ᚺᛖᚦᚱᛟᛞᚹᛖᚷᚲ"},
    {"id": "53_1",  "latin": "ekgudijaungandizih",        "runes": "ᛖᚲᚷᚢᛞᛁᛃᚨᚢᛜᚨᚾᛞᛁᛉᛁᚺ"},
    {"id": "82_1",  "latin": "saligastiz",               "runes": "ᛊᚨᛚᛁᚷᚨᛊᛏᛁᛉ"},
    {"id": "263_14","latin": "oþaainri farkanio",         "runes": "ᛟᚦᚨᚨᛁᚾᚱᛁ ᚠᚨᚱᚲᚨᚾᛟ"},
    {"id": "7404",  "latin": "lit at fa",                "runes": "ᛚᛁᛏ ᚨᛏ ᚠᚨ"},
]

IMAGE_DIR = r"C:\Users\USER\Desktop\GRAD_WORk\VAL_DATASET_GROQ"
EXTENSIONS = ('.png', '.jpg', '.jpeg', '.webp', '.gif')
NUM_RUNS = 3

# %%
PROMPT_TEXT = propmpt_text

# %%
MODELS = [
    'meta-llama/llama-4-scout-17b-16e-instruct',
    "llama-3.2-11b-vision-preview",
    "llama-3.2-90b-vision-preview",
]

# ==================== METRICS ====================

def character_accuracy(pred: str, gold: str) -> float:
    """Per-character accuracy (how many chars match positionally)"""
    if not gold:
        return 1.0 if not pred else 0.0
    matches = sum(p == g for p, g in zip(pred, gold))
    return matches / max(len(pred), len(gold))

def exact_match(pred: str, gold: str) -> bool:
    return pred.strip() == gold.strip()

def levenshtein(s1: str, s2: str) -> int:
    """Edit distance between two strings"""
    m, n = len(s1), len(s2)
    dp = list(range(n + 1))
    for i in range(1, m + 1):
        prev = dp[:]
        dp[0] = i
        for j in range(1, n + 1):
            if s1[i-1] == s2[j-1]:
                dp[j] = prev[j-1]
            else:
                dp[j] = 1 + min(prev[j], dp[j-1], prev[j-1])
    return dp[n]

def normalized_edit_distance(pred: str, gold: str) -> float:
    """0.0 = perfect, 1.0 = completely wrong"""
    if not gold and not pred:
        return 0.0
    dist = levenshtein(pred, gold)
    return dist / max(len(pred), len(gold), 1)

# ==================== IMAGE UTILS ====================

def find_image(image_id: str) -> str | None:
    """Find image file by ID (filename without extension)"""
    for fname in os.listdir(IMAGE_DIR):
        name, ext = os.path.splitext(fname)
        if name == image_id and ext.lower() in EXTENSIONS:
            return os.path.join(IMAGE_DIR, fname)
    return None

def encode_image(path: str) -> tuple[str, str]:
    ext = os.path.splitext(path)[1].lower()
    mime = "image/png" if ext == ".png" else "image/jpeg"
    with open(path, "rb") as f:
        return base64.b64encode(f.read()).decode('utf-8'), mime

# %%
import os
import base64
import time
import json
from datetime import datetime
from groq import Groq

def run_groq(image_path: str, model: str) -> str:
    image_data, mime = encode_image(image_path)
    response = client.chat.completions.create(
        model=model,
        messages=[{
            "role": "user",
            "content": [
                {"type": "image_url", "image_url": {"url": f"data:{mime};base64,{image_data}"}},
                {"type": "text", "text": PROMPT_TEXT}
            ]
        }],
        max_tokens=200,
        temperature=0.0
    )
    return response.choices[0].message.content.strip()

# ==================== VALIDATION LOOP ====================

def run_validation():
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    log_path = os.path.join(IMAGE_DIR, f"validation_{timestamp}.json")
    summary_path = os.path.join(IMAGE_DIR, f"summary_{timestamp}.txt")

    all_results = {}  # model -> list of per-sample results

    for model in MODELS:
        print(f"\n{'='*60}")
        print(f"MODEL: {model}")
        print(f"{'='*60}")
        all_results[model] = []

        for sample in GOLDEN_DATASET:
            sid = sample["id"]
            gold = sample["runes"]

            image_path = find_image(sid)
            if not image_path:
                print(f"  [{sid}] ⚠️  Изображение не найдено, пропускаю")
                continue

            sample_result = {
                "id": sid,
                "gold": gold,
                "runs": []
            }

            for run_idx in range(1, NUM_RUNS + 1):
                print(f"  [{sid}] run {run_idx}/{NUM_RUNS} ...", end=" ", flush=True)
                try:
                    pred = run_groq(image_path, model)
                    em  = exact_match(pred, gold)
                    cha = character_accuracy(pred, gold)
                    ned = normalized_edit_distance(pred, gold)

                    run_data = {
                        "run": run_idx,
                        "prediction": pred,
                        "exact_match": em,
                        "char_accuracy": round(cha, 4),
                        "norm_edit_dist": round(ned, 4),
                    }
                    sample_result["runs"].append(run_data)

                    status = "✅" if em else "❌"
                    print(f"{status}  pred='{pred}'  gold='{gold}'  CHA={cha:.2f}  NED={ned:.2f}")

                except Exception as e:
                    print(f"💥 Ошибка: {e}")
                    sample_result["runs"].append({"run": run_idx, "error": str(e)})

                time.sleep(4)  # rate limit

            all_results[model].append(sample_result)

    # ==================== AGGREGATE METRICS ====================

    print(f"\n{'='*60}")
    print("ИТОГОВЫЕ МЕТРИКИ")
    print(f"{'='*60}")

    summary_lines = []
    json_output = {"timestamp": timestamp, "models": {}}

    for model, samples in all_results.items():
        em_scores, cha_scores, ned_scores = [], [], []

        for sample in samples:
            for run in sample["runs"]:
                if "error" in run:
                    continue
                em_scores.append(int(run["exact_match"]))
                cha_scores.append(run["char_accuracy"])
                ned_scores.append(run["norm_edit_dist"])

        if not em_scores:
            continue

        avg_em  = sum(em_scores)  / len(em_scores)
        avg_cha = sum(cha_scores) / len(cha_scores)
        avg_ned = sum(ned_scores) / len(ned_scores)

        line = (
            f"\n{model}\n"
            f"  Exact Match:          {avg_em*100:.1f}%  ({sum(em_scores)}/{len(em_scores)})\n"
            f"  Char Accuracy:        {avg_cha*100:.1f}%\n"
            f"  Norm Edit Distance:   {avg_ned:.4f}  (0=perfect)\n"
        )
        print(line)
        summary_lines.append(line)

        json_output["models"][model] = {
            "exact_match_pct": round(avg_em * 100, 2),
            "char_accuracy_pct": round(avg_cha * 100, 2),
            "norm_edit_dist": round(avg_ned, 4),
            "total_runs": len(em_scores),
            "samples": samples
        }

    # ==================== SAVE LOGS ====================

    with open(log_path, "w", encoding="utf-8") as f:
        json.dump(json_output, f, ensure_ascii=False, indent=2)

    with open(summary_path, "w", encoding="utf-8") as f:
        f.write(f"Validation run: {timestamp}\n")
        f.writelines(summary_lines)

    print(f"\n📄 JSON лог:    {log_path}")
    print(f"📄 Summary:     {summary_path}")

if __name__ == "__main__":
    run_validation()
# Out:
# ============================================================
# MODEL: meta-llama/llama-4-scout-17b-16e-instruct
# ============================================================
#   [6_1] run 1/3 ... ❌  pred='## Step 1: Examine the image and identify the runic carvings
# The image shows a broken stone or ceramic piece with runic inscriptions. The visible runes appear to be in the Elder Futhark.
#
# ## 2: Transcribe the runes from left to right
# Starting from the left, the first rune appears to be ᛒ, followed by ᛁ, then ᛃ, then ᛗ, then ᚴ, then ᛋ, then ᛏ, then ᚾ, then ᛁ, then ᚷ, then ᚾ, then ᚹ.
#
# ## 3: Verify the runes against the Elder Futhark reference table
# Verifying each rune against the provided reference table:
# - ᛒ = B
# - ᛁ = I
# - ᛃ = J
# - ᛗ = M
# - ᚴ = K
# - ᛋ = S'  gold='ᛒᛁᛞᚨᚹᚨᚱᛁᛃᚨᛉᛏᚨᛚᚷᛁᛞᚨᛁ'  CHA=0.00  NED=0.99
#   [6_1] run 2/3 ... ❌  pred='## Step 1: Examine the Image
# The image shows a runic inscription on a broken stone or ceramic piece. The inscription appears to be in Elder Futhark runes.
#
# ## 2: Identify Individual Runes
# Starting from the left, the first rune appears to be ᛒ. The second rune looks like ᛁ. The third rune seems to be ᛗ. The fourth rune is ᛒ. The fifth rune appears to be ᛁ. The sixth rune looks like ᚾ. The seventh rune seems to be ᛃ. The eighth rune appears to be ᚾ. The ninth rune looks like ᚷ. The tenth rune seems to be ᚻ. The eleventh rune appears to be ᚾ.
#
# ## 3: Check for Bind Runes or Damage
# There are no obvious bind runes or significant damage that would alter the identification of the runes.
#
# ## 4: Transcribe the Runes
# Trans'  gold='ᛒᛁᛞᚨᚹᚨᚱᛁᛃᚨᛉᛏᚨᛚᚷᛁᛞᚨᛁ'  CHA=0.00  NED=0.99
#   [6_1] run 3/3 ... ❌  pred='## Step 1: Examine the Image and Identify Runes
# The image shows a runic inscription that appears to be weathered and cracked. We need to carefully examine each part of the inscription to identify the runes.
#
# ## 2: Break Down the Inscription
# Starting from the left, we see a rune that resembles ᛒ. Next to it, there seems to be ᛁᛗᛁ. Then, there's a possible ᛃ or ᚦ, but given the context and shape, it seems more aligned with ᚦ or another rune. Continuing, we observe sequences that could represent ᛗᛁᚾᚢ, and then what looks like ᚾᛁ.
#
# ## 3: Detailed Rune Identification
# - The first rune appears to be ᛒ.
# - The next is ᛁ.
# - Then, ᛗ.
# - Followed by ᛁ.
# - The sequence continues with'  gold='ᛒᛁᛞᚨᚹᚨᚱᛁᛃᚨᛉᛏᚨᛚᚷᛁᛞᚨᛁ'  CHA=0.00  NED=0.99
#   [13_0] run 1/3 ... ❌  pred='## Step 1: Examine the Image
# The image provided appears to be a sketch or drawing of a runic inscription. Given the nature of the task, the focus will be on identifying the Elder Futhark runes based on their characteristic shapes.
#
# ## 2: Identify Individual Runes
# Starting from the left:
# - The first rune appears to be ᚦ (TH) due to its vertical line with a triangle or thorn on the right.
# - The second rune seems to be ᚨ (A) with a vertical line and two diagonals forming a peak at the top.
# - The third rune looks like ᚱ (R) with a vertical line and a diagonal leg going right-down.
# - The fourth rune seems to be ᚺ (H) with two verticals connected by a horizontal line.
# - The fifth rune appears to be ᛁ (I) as a single vertical stroke.
# - The sixth rune resembles ᛊ (S) with a diagonal'  gold='ᛚᚢᚨ'  CHA=0.00  NED=1.00
#   [13_0] run 2/3 ... ❌  pred='## Step 1: Examine the image carefully
# The image appears to be a sketch of a runic inscription. We need to carefully examine the image to identify the individual runes.
#
# ## Step 2: Identify the runes
# Starting from the left, the first rune appears to be ᚾ (N). The second rune seems to be ᚢ (U). The third rune looks like ᚦ (TH). The fourth rune resembles ᚨ (A). The fifth rune appears to be ᚱ (R). The sixth rune seems to be ᚲ (K).
#
# ## Step 3: Continue identifying the runes
# Moving to the next section, the seventh rune appears to be ᛁ (I). The eighth rune seems to be ᚾ (N). The ninth rune looks like ᛁ (I). The tenth rune resembles ᚷ (G).
#
# ## 4: Identify the remaining runes
# The eleventh rune appears to be'  gold='ᛚᚢᚨ'  CHA=0.00  NED=1.00
#   [13_0] run 3/3 ... ❌  pred='## Step 1: Examine the Image
# The image provided appears to be a sketch of a runic inscription. However, the image is not clear, and some parts seem to be damaged or weathered.
#
# ## 2: Identify the Runes
# Starting from the left, we will attempt to identify each rune based on the Elder Futhark reference table provided.
#
# ## 3: Analyze the First Rune
# The first rune on the left appears to have a vertical line with two diagonal branches pointing right from the vertical, which matches the rune ᚠ.
#
# ## 4: Analyze the Second Rune
# The second rune seems to be a V-shape or two diagonals going down, which corresponds to ᚢ.
#
# ## 5: Analyze the Third Rune
# The third rune looks like a vertical line with a triangle or thorn on the right, matching ᚦ.
#
# ## 6: Analyze the Fourth Rune
# The fourth rune appears to be a vertical line with two diagonals forming a peak'  gold='ᛚᚢᚨ'  CHA=0.00  NED=1.00
#   [14_1] run 1/3 ... ❌  pred='## Step 1: Examine the image and identify the runes
# The image shows a runic carving with several runes. We will examine each rune from left to right.
#
# ## 2: Identify the first rune
# The first rune appears to be ᚨ (A) with a vertical line and two diagonals forming a peak at the top.
#
# ## 3: Identify the second rune
# The second rune seems to be ᚱ (R) with a vertical line and a diagonal leg going right-down.
#
# ## 4: Identify the third rune
# The third rune looks like ᚴ (K) is not present, but ᚲ (K) has two diagonals pointing left; however, the image shows a rune that could be ᚺ (H) or another, but given the shape, it seems more aligned with ᚺ (H) due to its structure of two verticals connected by a horizontal.
#
# ## 5: Identify the fourth rune
# The'  gold='ᛟᚹᛚᚦᚢᚦᛖᚹᚨᛉ'  CHA=0.00  NED=1.00
#   [14_1] run 2/3 ... ❌  pred='## Step 1: Examine the image and identify the runes
# The image shows a runic carving with several runes. We need to carefully examine each rune and match it to the Elder Futhark reference table.
#
# ## Step 2: Identify the individual runes
# Starting from the left, the first rune appears to be ᚱ. The second rune looks like ᚲ. The third rune seems to be ᚨ. The fourth rune resembles ᚾ. The fifth rune appears to be ᚻ. The sixth rune looks like ᚺ. The seventh rune seems to be ᚾ. The eighth rune resembles ᚨ.
#
# ## Step 3: Verify the runes and sequence
# Verify the sequence: ᚱᚲᚨᚾᚻᚺᚾᚨ.
#
# ## 4th rune re-evaluation
# Upon re-examining the 4th rune, it seems more'  gold='ᛟᚹᛚᚦᚢᚦᛖᚹᚨᛉ'  CHA=0.00  NED=1.00
#   [14_1] run 3/3 ... ❌  pred='## Step 1: Examine the Image
# The image provided appears to be a runic carving, possibly on a stone or metal surface, with a unique design that includes several runes. The carving seems to have a decorative or symbolic shape, but the focus is on deciphering the runic inscription.
#
# ## 2: Identify Individual Runes
# Looking closely at the image, the runes seem to be:
# - Starting from the left, the first rune resembles ᚱ (R) due to its vertical line with a diagonal leg going right-down.
# - The next rune appears to be ᚢ (U) because of its V-shape.
# - The third rune looks like ᚦ (TH) with a vertical line and a triangle/thorn on the right.
# - The fourth rune seems to be ᚨ (A) with a vertical line and two diagonals forming a peak at the top.
# - The fifth rune could be ᚱ (R) similar to the'  gold='ᛟᚹᛚᚦᚢᚦᛖᚹᚨᛉ'  CHA=0.00  NED=1.00
#   [15_1] run 1/3 ... ❌  pred='## Step 1: Examine the image and identify the runes
# The image shows a runic carving with several runes. We will examine each rune from left to right.
#
#
# ## 2: Identify the individual runes
# Starting from the left, the first rune appears to be ᚢ (U), followed by ᚦ (TH), then ᚨ (A), then ᚱ (R), then ᚲ (K), and finally ᚨ (A) and ᚦ (TH) again but possibly another rune next to them.
#
#
# ## 3: Detailed rune identification
# - The first rune is ᚢ (U).
# - The second rune is ᚦ (TH).
# - The third rune is ᚨ (A).
# - The fourth rune seems to be ᚱ (R).
# - The fifth rune appears to be ᚲ (K).
# - The sixth rune looks like ᚷ (G).
#
#
# ## 4:'  gold='ᚨᚾᛊᚷᛉᚺ'  CHA=0.00  NED=1.00
#   [15_1] run 2/3 ... ❌  pred='## Step 1: Examine the image and identify the runic carvings
# The image shows a runic carving with several Elder Futhark runes. The carvings appear to be weathered, but the shapes of the runes can still be discerned.
#
# ## 2: Identify the individual runes from left to right
# Starting from the left, the first rune appears to be ᚢ (U), given its V-shape. The next rune seems to be ᚦ (TH), recognizable by its vertical line with a triangle or thorn on the right. The third rune looks like ᚨ (A), with a vertical line and two diagonals forming a peak at the top. The fourth rune seems to be ᚱ (R), identified by its vertical line with a diagonal leg going right-down. The fifth rune appears to be ᚲ (K), with a vertical line and two diagonals pointing left. The sixth rune resembles ᚦ ('  gold='ᚨᚾᛊᚷᛉᚺ'  CHA=0.00  NED=1.00
#   [15_1] run 3/3 ... ❌  pred='## Step 1: Analyze the given image and identify the runic carvings.
# The image shows a runic inscription that needs to be transcribed using the Elder Futhark runes provided.
#
#
# ## 2: Match the runic carvings to the Elder Futhark reference table.
# Starting from the left, the first rune appears to be ᚢ (U), given its V-shape. The next rune seems to be ᚦ (TH), characterized by a vertical line with a triangle or thorn on the right. The third rune looks like ᚨ (A), with a vertical line and two diagonals forming a peak at the top. The fourth rune resembles ᚾ (N), with two vertical lines and a diagonal line between them. The fifth rune seems to be ᚢ (U) again, similar to the first one. The sixth rune appears to be ᚦ (TH), similar to the second one.
#
#
# ## 3: Continue matching the'  gold='ᚨᚾᛊᚷᛉᚺ'  CHA=0.00  NED=1.00
#   [16_3_2] ⚠️  Изображение не найдено, пропускаю
#   [39_1] run 1/3 ... ❌  pred='## Step 1: Examine the image and identify the runes
# The image shows a runic carving on a stone. The runes appear to be in the Elder Futhark script. We need to carefully examine the image to identify each rune.
#
#
# ## 2: Identify the individual runes
# Starting from the left, the first rune appears to be ᚨ, followed by ᛏ, then ᚨ, then ᚱ, and finally ᚨ.
#
#
# ## 3: Verify the runes against the Elder Futhark reference table
# Verifying each rune against the provided Elder Futhark reference table:
# - The first rune is ᚨ (A)
# - The second rune is ᛏ (T)
# - The third rune is ᚨ (A)
# - The fourth rune is ᚱ (R)
# - The fifth rune is ᚨ (A)
#
#
# ## 4: Consider bind runes and weathering
# There are no obvious'  gold='ᛚᛖᚦᚱᛟ'  CHA=0.00  NED=1.00
#   [39_1] run 2/3 ... ❌  pred='## Step 1: Examine the image and identify the runes
# The image shows a weathered stone or metal surface with runic carvings. The carvings appear to be in Elder Futhark runes, and we need to transcribe them accurately.
#
# ## 2: Locate and identify each rune
# Starting from the left, we see what appears to be ᛗ, then ᛏ, followed by ᚨ, then ᚱ, and finally ᚱ and ᚨ again.
#
# ## 3: Verify the runes against the Elder Futhark reference table
# - The first rune looks like ᛗ (M).
# - The second rune resembles ᛏ (T).
# - The third rune seems to be ᚨ (A).
# - The fourth and fifth runes appear to be ᚱ (R) repeated, and the last one seems to be ᚨ (A).
#
# ## 4: Transcribe the runes'  gold='ᛚᛖᚦᚱᛟ'  CHA=0.00  NED=1.00
#   [39_1] run 3/3 ... ❌  pred='## Step 1: Examine the Image
# The image shows a runic carving on a stone or similar material. The carving appears to be weathered and has several scratches and marks.
#
# ## 2: Identify the Runes
# Starting from the left, the first rune appears to be ᛗ (M) due to its shape with two verticals connected by an arch. The next rune seems to be ᛏ (T) because of its vertical line with two short diagonals at the top, resembling an arrowhead. Following that, there is what looks like ᛁ (I) as it is a single vertical stroke. Then, there appears to be ᚱ (R) with a vertical line and a diagonal leg going right-down. The next character seems to be ᚨ (A) with a vertical line and two diagonals forming a peak at the top. Lastly, there are two runes that resemble ᚱ (R).
#
# ## 3: Trans'  gold='ᛚᛖᚦᚱᛟ'  CHA=0.00  NED=1.00
#   [42_2] run 1/3 ... ❌  pred='## Step 1: Examine the Image and Identify the Runes
# The image shows a stone carving with runic inscriptions. The first step is to carefully examine the carving and identify the runes. The carving appears to have several runes etched into it, and there are two holes on either side.
#
# ## 2: Determine the Individual Runes
# Starting from the left, the first rune appears to be ᚴ (K) due to its shape with a vertical line and two diagonals pointing left. The next rune looks like ᚢ (U) with its V-shape. The third rune seems to be ᚦ (TH) with a vertical line and a triangle/thorn on the right. The fourth rune resembles ᚨ (A) with a vertical line and two diagonals forming a peak at the top. The fifth rune appears to be ᚱ (R) with a vertical line and a diagonal leg going right-down.
#
# ## 3:'  gold='ᚨᛚᚢᚲᛟ'  CHA=0.00  NED=1.00
#   [42_2] run 2/3 ... ❌  pred='## Step 1: Examine the Image and Identify the Runes
# The image shows a weathered stone with runic inscriptions. The first step is to carefully examine the image and identify the runes. Starting from the left, there appears to be a rune that could be ᚠ, followed by a rune that resembles ᚢ, then ᚦ, ᚨ, ᚱ, and ᚲ.
#
# ## 2: Confirm the Sequence of Runes
# Upon closer inspection, the sequence seems to match the Elder Futhark runes. The leftmost rune has two diagonal branches pointing to the right, suggesting ᚠ. The next one is a V-shape, indicating ᚢ. The third rune has a vertical stroke with a triangle or thorn on the right, which is ᚦ. The fourth rune has a vertical stroke with two diagonals forming a peak at the top, suggesting ᚨ. The fifth rune appears to have a vertical'  gold='ᚨᛚᚢᚲᛟ'  CHA=0.00  NED=1.00
#   [42_2] run 3/3 ... ❌  pred='## Step 1: Examine the Image
# The image shows a weathered stone with runic inscriptions. The runes appear to be carved in a sequence.
#
# ## Step 2: Identify the Runes
# Starting from the left, the first rune appears to be ᚨ (A) due to its vertical stroke with two diagonals forming a peak at the top.
#
# ## 3: Continue Identifying Runes
# The next rune seems to be ᚢ (U) because of its V-shape.
#
# ## 4: Identify the Third Rune
# The third rune looks like ᚦ (TH) with a vertical stroke and a triangle/thorn on the right.
#
# ## 5: Identify the Fourth Rune
# The fourth rune appears to be ᚨ (A) again, similar to the first one.
#
# ## 6: Identify the Fifth Rune
# The fifth rune seems to be ᚱ (R) with a vertical stroke and a diagonal leg going right-down.
#
# ## 7'  gold='ᚨᛚᚢᚲᛟ'  CHA=0.00  NED=1.00
#   [50_1] run 1/3 ... ❌  pred='## Step 1: Examine the Image
# The image shows a weathered stone with a runic inscription. The inscription appears to be in Elder Futhark runes.
#
# ## 2: Identify Individual Runes
# Starting from the left, the first rune seems to be ᚢ (U) due to its V-shape. The next rune could be ᚦ (TH) because of the vertical line with a triangle/thorn on the right. The third rune looks like ᚨ (A) with a vertical line and two diagonals forming a peak at the top.
#
# ## 3: Continue Identifying Runes
# The fourth rune appears to be ᚱ (R) with a vertical line and a diagonal leg going right-down. The fifth rune seems to be ᚲ (K) due to its vertical line with two diagonals pointing left. The sixth rune could be ᚷ (G) with a vertical line and an X or diagonal cross.
#
# ## 4: Further'  gold='ᚺᛖᚦᚱᛟᛞᚹᛖᚷᚲ'  CHA=0.00  NED=1.00
#   [50_1] run 2/3 ... ❌  pred='## Step 1: Examine the Image
# The image provided appears to be a weathered stone with a runic inscription. The inscription seems to be in Elder Futhark, given the time period and type of runes.
#
# ## 2: Identify Individual Runes
# Starting from the left, the first rune appears to be ᚠ (F) due to its two diagonal branches pointing right from a vertical stroke.
#
# ## 3: Continue Identifying Runes
# The next rune looks like ᚢ (U) with its V-shape.
#
# ## 4: Identify Remaining Runes
# Continuing to the right:
# - The third rune seems to be ᚦ (TH) with a vertical stroke and a triangle/thorn on the right.
# - The fourth rune resembles ᚨ (A) with a vertical stroke and two diagonals forming a peak at the top.
# - The fifth rune appears to be ᚱ (R) with a vertical stroke and a diagonal leg going right-down'  gold='ᚺᛖᚦᚱᛟᛞᚹᛖᚷᚲ'  CHA=0.00  NED=1.00
#   [50_1] run 3/3 ... ❌  pred='## Step 1: Examine the Image
# The image provided appears to be a weathered stone with a runic inscription. The inscription seems to be in Elder Futhark runes, given the context and the reference table provided.
#
# ## 2: Identify Individual Runes
# Starting from the left, we identify each rune based on its shape and compare it to the Elder Futhark reference table.
#
# ## 3: Transcribe the Runes
# The first rune appears to be ᚢ (U) due to its V-shape.
# The next rune looks like ᚦ (TH) with a vertical line and a triangle/thorn on the right.
# The third rune seems to be ᚨ (A) with a vertical line and two diagonals forming a peak at the top.
# The fourth rune resembles ᚱ (R) with a vertical line and a diagonal leg going right-down.
# The fifth rune appears to be ᚲ (K) with a vertical line and two'  gold='ᚺᛖᚦᚱᛟᛞᚹᛖᚷᚲ'  CHA=0.00  NED=1.00
#   [53_1] run 1/3 ... ❌  pred='## Step 1: Examine the Image and Identify Runes
# The image shows a runic inscription on a stone. The task is to perform an accurate OCR (Optical Character Recognition) of the runic carving using the Elder Futhark runes provided.
#
# ## 2: Break Down the Inscription
# Starting from the left, we identify each rune based on its shape and compare it to the Elder Futhark reference table.
#
# ## 3: Identify Individual Runes
# - The first rune appears to be ᚢ (U) due to its V-shape.
# - The second rune seems to be ᚦ (TH) with a vertical stroke and a triangle/thorn on the right.
# - The third rune looks like ᚨ (A) with a vertical stroke and two diagonals forming a peak at the top.
# - The fourth rune resembles ᚱ (R) with a vertical stroke and a diagonal leg going right-down.
# - The fifth rune is likely ᚲ'  gold='ᛖᚲᚷᚢᛞᛁᛃᚨᚢᛜᚨᚾᛞᛁᛉᛁᚺ'  CHA=0.00  NED=1.00
#   [53_1] run 2/3 ... ❌  pred='## Step 1: Examine the Image and Identify Runes
# The image shows a runic inscription on a stone. The task is to read the inscription from left to right using the Elder Futhark rune set provided.
#
# ## 2: Break Down the Inscription
# Starting from the left, we identify each rune based on its shape and compare it to the Elder Futhark reference table.
#
# ## 3: Identify Individual Runes
# - The first rune appears to be ᚾ (N).
# - The second rune looks like ᛁ (I).
# - The third rune seems to be ᚦ (TH).
# - The fourth rune resembles ᚨ (A).
# - The fifth rune is likely ᚱ (R).
# - The sixth rune appears to be ᚲ (K).
# - The seventh rune looks like ᚷ (G).
# - The eighth rune seems to be ᛁ (I).
# - The ninth rune appears to be ᚾ (N'  gold='ᛖᚲᚷᚢᛞᛁᛃᚨᚢᛜᚨᚾᛞᛁᛉᛁᚺ'  CHA=0.00  NED=1.00
#   [53_1] run 3/3 ... ❌  pred='## Step 1: Examine the Image and Identify Runes
# The image provided shows a runic inscription on a stone. The task is to accurately read the runes from left to right using the Elder Futhark reference table.
#
# ## 2: Break Down the Inscription
# Starting from the left, we identify each rune based on its shape and compare it to the Elder Futhark reference table.
#
# ## 3: Identify Individual Runes
# - The first rune appears to be ᚢ (U) due to its V-shape.
# - The second rune looks like ᚦ (TH) with a vertical line and a triangle/thorn on the right.
# - The third rune seems to be ᚨ (A) with a vertical line and two diagonals forming a peak at the top.
# - The fourth rune resembles ᚱ (R) with a vertical line and a diagonal leg going right-down.
# - The fifth rune is likely ᚲ (K) with a vertical'  gold='ᛖᚲᚷᚢᛞᛁᛃᚨᚢᛜᚨᚾᛞᛁᛉᛁᚺ'  CHA=0.00  NED=1.00
#   [82_1] run 1/3 ... ❌  pred='## Step 1: Examine the Image and Identify Runes
# The image shows a runic inscription on a stone surface. The inscription appears to be in Elder Futhark runes. We need to carefully examine each rune and match it to the closest shape in the Elder Futhark reference table.
#
# ## 2: Identify Individual Runes
# Starting from the top, the first rune appears to be ᚢ (U), given its V-shape. The next rune looks like ᚦ (TH), with a vertical line and a triangle/thorn on the right. The third rune seems to be ᚨ (A), characterized by a vertical line with two diagonals forming a peak at the top. The fourth rune resembles ᚱ (R), with a vertical line and a diagonal leg going right-down. The fifth rune appears to be ᚲ (K), identified by a vertical line with two diagonals pointing left. The sixth rune looks like ᚢ (U) again'  gold='ᛊᚨᛚᛁᚷᚨᛊᛏᛁᛉ'  CHA=0.00  NED=1.00
#   [82_1] run 2/3 ... ❌  pred='## Step 1: Examine the Image and Identify Runes
# The image shows a runic inscription on a stone surface. The inscription appears to be in Elder Futhark runes, which were used from approximately 200-700 CE. The runes are painted red and are oriented vertically.
#
# ## 2: Transcribe the Runes
# Starting from the top and moving down, we can see the following runes:
# - The first rune appears to be ᚢ (U) due to its V-shape.
# - The second rune looks like ᚱ (R) with a vertical line and a diagonal leg going right-down.
# - The third rune seems to be ᚨ (A) with a vertical line and two diagonals forming a peak at the top.
# - The fourth rune resembles ᚾ (N) with two verticals and a diagonal between them.
# - The fifth rune is ᚢ (U) similar to the first one.
# - The sixth rune appears to'  gold='ᛊᚨᛚᛁᚷᚨᛊᛏᛁᛉ'  CHA=0.00  NED=1.00
#   [82_1] run 3/3 ... ❌  pred='## Step 1: Examine the Image
# The image shows a runic inscription on a weathered stone surface. The inscription is written in red and appears to be in the Elder Futhark runic alphabet.
#
# ## 2: Identify Individual Runes
# Starting from the top, the first rune appears to be ᚢ (U), given its V-shape. The next rune looks like ᚦ (TH), with a vertical line and a triangle/thorn on the right. The third rune seems to be ᚨ (A), characterized by a vertical line with two diagonals forming a peak at the top.
#
# ## 3: Continue Identifying Runes
# The fourth rune resembles ᚱ (R), with a vertical line and a diagonal leg going right-down. The fifth rune appears to be ᚲ (K), identified by a vertical line with two diagonals pointing left. The sixth rune looks like ᚷ (G), with a vertical line and an X or diagonal cross'  gold='ᛊᚨᛚᛁᚷᚨᛊᛏᛁᛉ'  CHA=0.00  NED=1.00
#   [263_14] run 1/3 ... ❌  pred='## Step 1: Examine the Runic Inscription
# The image provided shows a runic inscription carved into a stone. The inscription appears to be in the Elder Futhark runic alphabet, which was used from approximately 200 to 700 CE.
#
# ## Step 2: Identify Individual Runes
# Starting from the top of the inscription and moving downwards, we can see the following runes:
# - The first rune appears to be ᚢ (U).
# - The second rune seems to be ᚱ (R).
# - The third rune looks like ᚨ (A).
# - The fourth rune is likely ᚾ (N).
# - The fifth rune appears to be ᚴ (K).
# - The sixth rune seems to be ᛁ (I).
# - The seventh rune looks like ᚾ (N).
# - The eighth rune appears to be ᚷ (G).
#
# ## 3: Check for Bind Runes or Special Constructions
# There are no obvious'  gold='ᛟᚦᚨᚨᛁᚾᚱᛁ ᚠᚨᚱᚲᚨᚾᛟ'  CHA=0.00  NED=0.99
#   [263_14] run 2/3 ... ❌  pred='## Step 1: Analyzing the Runic Inscription
# The image provided shows a runic inscription carved into a stone. The task is to perform an accurate OCR (Optical Character Recognition) of the runic carving using the Elder Futhark runes reference table provided.
#
# ## Step 2: Identifying Individual Runes
# Starting from the top of the inscription and moving downwards, we identify each rune based on its shape and compare it to the Elder Futhark reference table.
#
# ## 3: Transcribing the Runes
# The inscription appears to read from top to bottom as follows:
# - The first rune is ᛏᚢᚦ (T, U, TH) but given the shape, it seems to start with ᛏ.
# - Continuing this process for each rune.
#
# ## 4: Detailed Rune Identification
# Upon closer inspection, the sequence seems to be:
# ᛏᚢᚦᚨᚱᚲ'  gold='ᛟᚦᚨᚨᛁᚾᚱᛁ ᚠᚨᚱᚲᚨᚾᛟ'  CHA=0.00  NED=1.00
#   [263_14] run 3/3 ... ❌  pred='## Step 1: Examine the Image
# The image shows a runic inscription on a stone. The inscription is vertical and appears to be in Elder Futhark.
#
# ## Step 2: Identify Individual Runes
# Starting from the top, the first rune appears to be ᚢ (U), given its V-shape.
#
# ## 3: Continue Identifying Runes
# The next rune seems to be ᚦ (TH), characterized by a vertical line with a triangle or thorn on the right.
#
# ## 4: Further Identification
# The third rune looks like ᚨ (A), with a vertical line and two diagonals forming a peak at the top.
#
# ## 5: Identify the Rest of the Runes
# Continuing down the inscription:
# - The fourth rune appears to be ᚱ (R), with a vertical line and a diagonal leg going right-down.
# - The fifth rune seems to be ᚲ (K), identified by its vertical line with two diagonals pointing left'  gold='ᛟᚦᚨᚨᛁᚾᚱᛁ ᚠᚨᚱᚲᚨᚾᛟ'  CHA=0.00  NED=0.99
#   [7404] ⚠️  Изображение не найдено, пропускаю
#
# ============================================================
# MODEL: llama-3.2-11b-vision-preview
# ============================================================
#   [6_1] run 1/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [6_1] run 2/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [6_1] run 3/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [13_0] run 1/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [13_0] run 2/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [13_0] run 3/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [14_1] run 1/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [14_1] run 2/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [14_1] run 3/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [15_1] run 1/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [15_1] run 2/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [15_1] run 3/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [16_3_2] ⚠️  Изображение не найдено, пропускаю
#   [39_1] run 1/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [39_1] run 2/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [39_1] run 3/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [42_2] run 1/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [42_2] run 2/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [42_2] run 3/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [50_1] run 1/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [50_1] run 2/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
#   [50_1] run 3/3 ... 💥 Ошибка: Error code: 400 - {'error': {'message': 'The model `llama-3.2-11b-vision-preview` has been decommissioned and is no longer supported. Please refer to https://console.groq.com/docs/deprecations for a recommendation on which model to use instead.', 'type': 'invalid_request_error', 'code': 'model_decommissioned'}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 139
#     136     print(f"📄 Summary:     {summary_path}")
#     138 if __name__ == "__main__":
# --> 139     run_validation()
#
# Cell In[40], line 78, in run_validation()
#      75                 print(f"💥 Ошибка: {e}")
#      76                 sample_result["runs"].append({"run": run_idx, "error": str(e)})
# ---> 78             time.sleep(4)  # rate limit
#      80         all_results[model].append(sample_result)
#      82 # ==================== AGGREGATE METRICS ====================
#
# KeyboardInterrupt:
